# %% [markdown]
# <a href="https://colab.research.google.com/github/manohar-billa/CODESOFT/blob/main/MOVIE_GENRE_CLASSIFICATION_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install SVM
# Out:
# Collecting SVM
#   Downloading svm-0.1.0.tar.gz (3.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from SVM) (2.32.3)
# Collecting colorama (from SVM)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting xmltodict (from SVM)
#   Downloading xmltodict-0.14.2-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->SVM) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->SVM) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->SVM) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->SVM) (2025.8.3)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading xmltodict-0.14.2-py2.py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: SVM
#   Building wheel for SVM (setup.py) ... done
#   Created wheel for SVM: filename=svm-0.1.0-py3-none-any.whl size=3465 sha256=58b1ff0587be4ccdb3f7c8949f36d83dde95fdcf74da8436b4d1e59aef83edcb
#   Stored in directory: /root/.cache/pip/wheels/9c/73/7e/56180f865dd2324b2ebca0105dc0d3a88a2ed5e053e06f946d
# Successfully built SVM
# Installing collected packages: xmltodict, colorama, SVM
# Successfully installed SVM-0.1.0 colorama-0.4.6 xmltodict-0.14.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re  # used for pattern matching and text manipulation.
import string
import nltk #a powerful library for working with human language data.
from nltk.corpus import stopwords #for cleaning
from nltk.stem import LancasterStemmer ##for cleaning
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
train_path= "/content/sample_data/train_data.txt.zip"
train_data = pd.read_csv(train_path, sep=":::", names=["TITLE", "GENRE", "DESCRIPTION"], engine="python")

# %%
train_data
# Out:
#                                               TITLE          GENRE  \
# 1                     Oscar et la dame rose (2009)          drama
# 2                                     Cupid (1997)       thriller
# 3                 Young, Wild and Wonderful (1980)          adult
# 4                            The Secret Sin (1915)          drama
# 5                           The Unrecovered (2007)          drama
# ...                                             ...            ...
# 54210                              "Bonino" (1953)         comedy
# 54211                  Dead Girls Don't Cry (????)         horror
# 54212    Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54213                     Make Your Own Bed (1944)         comedy
# 54214   Nature's Fury: Storm of the Century (2006)        history
#
#                                              DESCRIPTION
# 1       Listening in to a conversation between his do...
# 2       A brother and sister with a past incestuous r...
# 3       As the bus empties the students for their fie...
# 4       To help their unemployed father make ends mee...
# 5       The film's title refers not only to the un-re...
# ...                                                  ...
# 54210   This short-lived NBC live sitcom centered on ...
# 54211   The NEXT Generation of EXPLOITATION. The sist...
# 54212   Ze bestaan echt, is a stand-up comedy about g...
# 54213   Walter and Vivian live in the country and hav...
# 54214   On Labor Day Weekend, 1935, the most intense ...
#
# [54214 rows x 3 columns]

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54214 entries, 1 to 54214
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   TITLE        54214 non-null  object
#  1   GENRE        54214 non-null  object
#  2   DESCRIPTION  54214 non-null  object
# dtypes: object(3)
# memory usage: 1.7+ MB

# %%
train_data.describe()
# Out:
#                                                TITLE    GENRE  \
# count                                          54214    54214
# unique                                         54214       27
# top      Nature's Fury: Storm of the Century (2006)    drama
# freq                                               1    13613
#
#                                               DESCRIPTION
# count                                               54214
# unique                                              54086
# top      Grammy - music award of the American academy ...
# freq                                                   12

# %%
train_data.isnull().sum()
# Out:
# TITLE          0
# GENRE          0
# DESCRIPTION    0
# dtype: int64

# %%
test_path= "/kaggle/input/genre-classification-dataset-imdb/Genre Classification Dataset/test_data.txt"
test_data = pd.read_csv(train_path, sep=":::", names=["ID","TITLE","DESCRIPTION"], engine="python")

# %%
test_data
# Out:
#                                                  ID          TITLE  \
# 1                     Oscar et la dame rose (2009)          drama
# 2                                     Cupid (1997)       thriller
# 3                 Young, Wild and Wonderful (1980)          adult
# 4                            The Secret Sin (1915)          drama
# 5                           The Unrecovered (2007)          drama
# ...                                             ...            ...
# 54210                              "Bonino" (1953)         comedy
# 54211                  Dead Girls Don't Cry (????)         horror
# 54212    Ronald Goedemondt: Ze bestaan echt (2008)    documentary
# 54213                     Make Your Own Bed (1944)         comedy
# 54214   Nature's Fury: Storm of the Century (2006)        history
#
#                                              DESCRIPTION
# 1       Listening in to a conversation between his do...
# 2       A brother and sister with a past incestuous r...
# 3       As the bus empties the students for their fie...
# 4       To help their unemployed father make ends mee...
# 5       The film's title refers not only to the un-re...
# ...                                                  ...
# 54210   This short-lived NBC live sitcom centered on ...
# 54211   The NEXT Generation of EXPLOITATION. The sist...
# 54212   Ze bestaan echt, is a stand-up comedy about g...
# 54213   Walter and Vivian live in the country and hav...
# 54214   On Labor Day Weekend, 1935, the most intense ...
#
# [54214 rows x 3 columns]

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54214 entries, 1 to 54214
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID           54214 non-null  object
#  1   TITLE        54214 non-null  object
#  2   DESCRIPTION  54214 non-null  object
# dtypes: object(3)
# memory usage: 1.7+ MB

# %%
plt.figure(figsize=(10,15))
sns.countplot(data=train_data, y="GENRE", order= train_data["GENRE"].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(27,7))
sns.countplot(data=train_data, x="GENRE", order= train_data["GENRE"].value_counts().index, palette = "YlGnBu")
plt.show()
# Out:
# /tmp/ipython-input-3096700157.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=train_data, x="GENRE", order= train_data["GENRE"].value_counts().index, palette = "YlGnBu")
